# %% [markdown]
# # APV Concept Demo
# This notebook runs the lightweight simulation of APV (see `run_demo.py`).

# %%
from apv_simulation import run_demo_save
run_demo_save('results.json')
print('Done')
